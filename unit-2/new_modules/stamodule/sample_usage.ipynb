# %% [markdown]
# # How to use mdensity?

# %% [markdown]
# ### You import with this line:

# %%
import stamodule.mdensity.velogen as dg

# %% [markdown]
# ### Generate plot:

# %%
fig3 = dg.get_map(100, "harmonic")
# Out:
# The grid has been generated.
# Plot is ready.
