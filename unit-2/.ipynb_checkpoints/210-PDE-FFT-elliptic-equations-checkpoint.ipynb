# %% [markdown]
# # Solve Poisson's equation
#
# $$\nabla^2 \phi = f$$
#
# for
#
# ![Screen%20Shot%202023-01-03%20at%2012.48.19.png](attachment:Screen%20Shot%202023-01-03%20at%2012.48.19.png)
#
# The analytical is:
#
#
# $$\phi = \sin(2\pi x)^2\cos(4\pi y) + \sin(4\pi x)\cos(2\pi y)^2$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Check analytical solution:

# %%
# Create an XY grid

# Set number of points
Nx = 64
Ny = 64

# Min/Max values for the axes
x_min = 0.
x_max = 1.

y_min = 0.
y_max = 1.

# step sizes 
dx = (x_max - x_min)/Nx
dy = (y_max - y_min)/Ny

#print(dx)
#print(dy)

# Axes:
x = np.arange(x_min, x_max, dx)
y = np.arange(y_min, y_max, dy)

print(x.shape, y.shape)

# We create the 2D domain
X, Y = np.meshgrid(x, y)

print(X.shape, Y.shape)
# Out:
# (64,) (64,)
# (64, 64) (64, 64)

# %% [markdown]
# Create function for:
#
#
# $$\phi(x, y) = \sin(2\pi x)^2\cos(4\pi y) + \sin(4\pi x)\cos(2\pi y)^2$$

# %%
def exact_sln(xx, yy):
    
    phi_exact = (np.sin(2*np.pi*xx)**2)*(np.cos(4*np.pi*yy)) + \
    (np.sin(4*np.pi*xx))*(np.cos(2*np.pi*yy)**2)
    
    return phi_exact

# %%
# Evaluate the function using our 2D grid

Z_sln = exact_sln(X, Y)

print(Z_sln.shape)
# Out:
# (64, 64)

# %% [markdown]
# ### Plotting:

# %%
# Figure environment

plt.figure(figsize=(6,4))

A = plt.pcolor(X, Y, Z_sln)

plt.colorbar(A)

plt.show()
