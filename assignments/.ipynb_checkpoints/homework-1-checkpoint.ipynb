# %% [markdown]
# # Homework 1 - Computational Physics 2
#
# - **Credits:** 20 points
#
#
# - **Deadline: Friday 22nd September 2023 (by 17h00)**
#
#
# - Please send your **.ipynb file** via email to wbanda@yachaytech.edu.ec
#
#
# - **This part should be submitted individually.**
#
#
# - You can call your notebook with your surname and also include your name on the notebook.
#
#
# ## Instructions:
#
#
# - Solve the following problems using python code.

# %% [markdown]
# ## Name:

# %% [markdown]
# ## Problem 1 (10 points): Euler methods for electric circuit ODEs
#
# Consider the electric circuit of the figure below. The circuit contains an electromotive force $E$ supplied by a battery, a resistance $R$, an inductor $L$, and a capacitor $C$, in series. If the charge on the capacitor at time $t$ is $Q=Q(t)$, then the current is the rate of change with respect to time, i.e. $I=\frac{dQ}{dt}$. The voltage drops across the resistor, inductor and capacitor are $RL$, $L\frac{dI}{dt}$, and $\frac{Q}{C}$, respectively.
#
# **Kirchhoff's Voltage Law** states that the algebraic sum of the potential differences in any loop must be equal to zero, so we get the following ODE:
#
# $$L\frac{dI}{dt} + RI + \frac{Q}{C}= E(t)$$
#
# Since $I=\frac{dQ}{dt}$,
#
# $$L\frac{d^2Q}{dt^2} + R\frac{dQ}{dt} + \frac{Q}{C}= E(t)$$
#
#
#
#
# We want to find the charge and current at time $t$ in this circuit, for which we consider a resistance of $R= 40\, \Omega$, $L = 1\,\rm H$, $C= 16\times10^{-4}\,\rm F$, and $E(t) = 100\,\rm V\cos(10\,s^{-1}\,t)$ for $0\leq t \leq 2\,\rm s$. The initial charge and current are both equal to $0$.
#
#
# (a) Write down the ODE (in the correct units) using the constants and function defined above.
#
#
# (b) Use sympy to find the analytical solution for $Q(t)$, and make a plot of $Q(t)$ vs. $t$. Does the circuit reach steady state?
#
#
# (c) Reduce the order of the ODE to first order, and write down the relevant explicit, implicit and trapezoidal Euler matrix equations. Hint: First define $S(t)$ and find $\frac{dS}{dt}$, then substitute into the explicit, implicit and trapezoidal Euler formulae reviewed in class.
#
#
# (d) Implement the explicit, implicit and trapezoidal Euler methods to find numerical solutions for $Q(t)$.
#
#
# (e) Make a plot of $Q(t)$ vs. $t$ comparing the numerical solutions with the analytical solution. Which method produces the best results?
#
# Reference image:
#
# https://github.com/wbandabarragan/computational-physics-2/blob/main/assignments/circuit.png
#
# ![circuit.png](attachment:circuit.png)

# %% [markdown]
# ## Problem 2 (10 points): RK methods for population dynamics ODEs
#
# The **Verhulst-Pearl model** is used to study animal population dynamics. This model is also called **logistic growth model** and assumes that $P(t)$ satisfies the following ODE:
#
#
# $$\frac{dP}{dt}=\alpha\,P\left(1-\frac{P}{\beta}\right)$$
#
#
# where $\alpha$ is the growth rate and $\beta$ is the limiting size for the population (also called the environment carrying capacity). Imagine we use this equation to study the population dynamics of a bird species re-introduced into nature, knowing that the test environment can only host $20$ individuals. We liberate $10$ individuals of this species in the wild, and we know that the growth rate is $0.2$ individuals per month.
#
# (a) Use sympy to find the analytical solution to this ODE for this set of conditions. Make a plot of the analytical solution and label it appropriately.
#
#
# (b) Based on the lectures on Runge-Kutta (RK) methods for ODEs, design a third-order RK method. Then, write a python function for the your RK3 integrator. The function should take the step size as an argument.
#
#
# (c) Find the approximate solution to this initial-value problem using:
#
# - the 3rd-order Runge-Kutta integrator developed in part (b).
#
# - the 2nd and 4th-order Runge-Kutta integrators developed in class.
#
# **Please note that you cannot use scipy solvers for this problem.**
#
# (d) Make a plot comparing the analytical and all approximate RK solutions. Which method produces the most accurate result and why?
#
#
# (e) Carry out a covergence study, i.e.:
#
# - plot the difference between the exact solution and the approximated solutions for four different step sizes (and for each integrator).
#
#
# - write a function to calculate the absolute errors. Then, make a single labeled plot of the errors versus the RK method order for all four different step sizes. Briefly comment on the results from your convergence study.
