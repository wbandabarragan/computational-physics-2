# %% [markdown]
# # Packaging
#
#
# Let's look at the structure of creating an installable python package.
#
# The python packaging system is constantly evolving, and the current recommendations
# of tools is list here: https://packaging.python.org/en/latest/guides/tool-recommendations/

# %%
import matplotlib.pyplot as plt
import numpy as np

def mandelbrot(N, xmin=-2.0, xmax=2.0, ymin=-2.0, ymax=2.0, max_iter=10):

    x = np.linspace(xmin, xmax, N)
    y = np.linspace(ymin, ymax, N)

    xv, yv = np.meshgrid(x, y, indexing="ij")

    c = xv + 1j*y

    z = np.zeros((N, N), dtype=np.complex128)

    m = np.zeros((N, N), dtype=int)

    for i in range(max_iter):
        z = z**2 + c

        m[np.logical_and(np.abs(z) > 2, m == 0)] = i

    fig, ax = plt.subplots()
    
    fig.set_size_inches=(8, 8)
    
    im = ax.imshow(np.transpose(m), extent=[xmin, xmax, ymin, ymax], clim=(0,20))

    fig.colorbar(im, ax=ax)

    return fig

# %%
mandelbrot(1000, xmin=-2.0, xmax=2.0, ymin=-2.0, ymax=2.0, max_iter=50)
# Out:
# /var/folders/sw/g1jmwgb9161cw02pzv6xtvjw0000gn/T/ipykernel_47021/4122525589.py:20: RuntimeWarning: overflow encountered in absolute
#   m[np.logical_and(np.abs(z) > 2, m == 0)] = i
# /var/folders/sw/g1jmwgb9161cw02pzv6xtvjw0000gn/T/ipykernel_47021/4122525589.py:18: RuntimeWarning: overflow encountered in square
#   z = z**2 + c
# /var/folders/sw/g1jmwgb9161cw02pzv6xtvjw0000gn/T/ipykernel_47021/4122525589.py:18: RuntimeWarning: invalid value encountered in square
#   z = z**2 + c
