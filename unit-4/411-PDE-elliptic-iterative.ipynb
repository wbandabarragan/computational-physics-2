# %% [markdown]
# # Finite-difference method: iterative technique
#
# ## Laplace equation:
#
# $$\nabla^2u=0$$
#
# where $u(x,y)$.
#
# $$\frac{\partial^2u}{\partial x^2}+\frac{\partial^2u}{\partial y^2}=0$$
#
#
# ## Problem:
#
# Solve the 2D Laplace equation considering the following domain:
#
# $0\leq x \leq a=6\pi$
#
# $0\leq y \leq b=\pi$
#
# and the following boundary conditions:
#
# $u(0,y)=0$
#
# $u(a,y)=\frac{\sinh{(\omega y})}{\sinh{(\omega b})}$
#
# $u(x,0)=0$
#
# $u(x,b)=\frac{\sin{(\omega x})}{\sin{(\omega a})}$
#
#
# ## 1. Analytical solution
#
# $$\frac{\partial^2u}{\partial x^2}+\frac{\partial^2u}{\partial y^2}=0$$
#
# We use variable separation:
#
# $u(x,y)=\theta(x)\,\phi(y)$
#
# We obtain:
#
# $$\phi\frac{\partial^2\theta}{\partial x^2}+\theta\frac{\partial^2\phi}{\partial y^2}=0$$
#
# $$\Rightarrow \frac{1}{\theta}\frac{d^2\theta}{d x^2}=-\frac{1}{\phi}\frac{d^2\phi}{d y^2}=\alpha$$
#
# Our resulting ODEs are:
#
# $\theta_{xx} -\alpha \theta=0$
#
# $\phi_{yy} +\alpha \phi=0$
#
#
# ### Case 1:
#
# If $\alpha=0$,
#
# $\theta=c_1x+c_2$
#
# $\phi=c_3y+c_4$
#
# ### Case 2:
#
# If $\alpha\neq0$, and $\alpha<0$:
#
# $\theta=c_1e^{i\sqrt{-\alpha}x}+c_2e^{-i\sqrt{-\alpha}x}$
#
# $\phi=c_1e^{\sqrt{-\alpha}y}+c_2e^{-\sqrt{-\alpha}y}$
#
# If $\alpha\neq0$, and $\alpha>0$:
#
# $\theta=c_1e^{\sqrt{-\alpha}x}+c_2e^{-\sqrt{-\alpha}x}$
#
# $\phi=c_1e^{i\sqrt{-\alpha}y}+c_2e^{-i\sqrt{-\alpha}y}$
#
# We introduce $\omega=\sqrt{-\alpha}$:
#
# $\theta=c_1e^{i \omega x}+c_2e^{-i \omega x}$
#
# $\phi=c_1e^{ \omega y}+c_2e^{- \omega y}$
#
# If $\alpha\neq0$, and $\alpha>0$:
#
# $\theta=c_1e^{\omega x}+c_2e^{-\omega x}$
#
# $\phi=c_1e^{i \omega y}+c_2e^{-i \omega y}$
#
# ## Solution for $\theta(x)$:
#
# $\theta(x)=\left\{
# \begin{array}{ll}
#       A\cos(\omega x) + B\sin(\omega x) & \alpha< 0 \\
#       C\,x+D & \alpha =0 \\
#       E\cosh(\omega x) + F\sinh(\omega x) & \alpha> 0 \\
# \end{array}
# \right.$
#
# ## Solution for $\phi(y)$:
#
# $\phi(y)=\left\{
# \begin{array}{ll}
#       A\cosh(\omega y) + B\sinh(\omega y) & \alpha< 0 \\
#       C\,y+D & \alpha =0 \\
#       E\cos(\omega y) + F\sin(\omega y) & \alpha> 0 \\
# \end{array}
# \right.$

# %% [markdown]
# ## Boundary condition analysis:
#
# ### 1. $u(0,y)=0$
#
# $$\Rightarrow \theta(0)=0$$
#
#
# ### 2. $u(a,y)=\frac{\sinh{(\omega y})}{\sinh{(\omega b})}$
#
# $$\Rightarrow \theta(a)=1$$
# $$\Rightarrow \phi(y)=\frac{\sinh{(\omega y})}{\sinh{(\omega b})}$$
#
# ### 3. $u(x,0)=0$
#
# $$\Rightarrow \phi(0)=0$$
#
# ### 4. $u(x,b)=\frac{\sin{(\omega x})}{\sin{(\omega a})}$
#
# $$\Rightarrow \theta(x)=\frac{\sin{(\omega x})}{\sin{(\omega a})}$$
# $$\Rightarrow \phi(b)=1$$

# %% [markdown]
# ## Solution after applying BCs:
#
# $$u(x,y)=\theta(x)\phi(y)=\frac{\sin(\omega x)}{\sin(\omega a)}\frac{\sinh(\omega y)}{\sinh(\omega b)}$$

# %% [markdown]
# ### Plotting the exact analytical solution:

# %%
# Import libraries

import numpy as np
import matplotlib.pyplot as plt

# %%
# Computational domain limits
a = 6*np.pi # for x 
b = np.pi   # for y

# Step sizes
nx = 200
ny = 100

# Differentials for x and y
dx = a/nx 
dy = b/ny

# Generate the vectors for x and y
x = np.arange(0, a, dx)
y = np.arange(0, b, dy)

#print(x.shape, y.shape)

# %%
# Meshgrid - 2D computational domain

x_2d, y_2d = np.meshgrid(x, y)

#print(x_2d.shape, y_2d.shape)

# %% [markdown]
# ### Exact solution
#
# $$u(x,y)=\theta(x)\phi(y)=\frac{\sin(\omega x)}{\sin(\omega a)}\frac{\sinh(\omega y)}{\sinh(\omega b)}$$
#
# For simplicity, we take:
# $\omega = 1$

# %%
def u_exact(xx, yy):
    """
    Function to evaluate the exact sln to the Laplace eq. for th
    given problem.
    Inputs: xx -> x_2d, yy ->  y_2d
    Ouput: surface for u(x,y)
    """
    
    u_sln = (np.sin(xx)/np.sin(a))*(np.sinh(yy)/np.sinh(b))
    
    return u_sln

# %%
# Evaluate using our meshgrid

u_exact_sln = u_exact(x_2d, y_2d)

#print(u_exact_sln.shape)

# %%
# Plotting

plt.figure(figsize=(5,4))

z1 = plt.pcolor(x_2d, y_2d, u_exact_sln, cmap = 'inferno')

plt.colorbar(z1)

plt.title("Exact solution")

plt.xlabel(r"$x$")
plt.ylabel(r"$y$")

plt.show()

# %% [markdown]
# ### 3D plot of the surface:

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# Plotting
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Plot the surface.
surf = ax.plot_surface(x_2d, y_2d, u_exact_sln, cmap = 'inferno', linewidth=0, antialiased=False)

plt.xlabel(r"$x$")
plt.ylabel(r"$y$")

plt.show()

# %% [markdown]
# ## 2. Numerical solution:
#
# Steps:
#
# - Discretising the domain: Replace the continuous domain with a grid of points.
#
# - Finite difference approximation: Use a stencil (typically 5-point in 2D or 7-point in 3D) to approximate the Laplace operator at each interior grid point using neighboring values.
#
# - Initial guess: Assign an initial value (e.g., zero or average boundary value) to all interior points.
#
# - Iterative update: Repeatedly update each interior point's value to the average of its neighbors (Gauss-Seidel or Jacobi method).
#
# - Convergence check: Continue iterating until the solution changes less than a small threshold (tolerance) across the grid.
#
#
# Second derivative in $x$:
#
# $$\frac{\partial^2 u}{\partial x^2}=\frac{u_{i+1,j}-2u_{i,j}+u_{i-1,j}}{(\Delta x)^2}$$
#
# Second derivative in $y$:
#
# $$\frac{\partial^2 u}{\partial y^2}=\frac{u_{i,j+1}-2u_{i,j}+u_{i,j-1}}{(\Delta y)^2}$$
#
#
# Placing into the Laplace equation:
#
# $$\frac{\partial^2 u}{\partial x^2}+\frac{\partial^2 u}{\partial y^2}=\frac{u_{i+1,j}-2u_{i,j}+u_{i-1,j}}{(\Delta x)^2}+\frac{u_{i,j+1}-2u_{i,j}+u_{i,j-1}}{(\Delta y)^2}=0$$
#
#
# Working algebraically and solving for the desired point $u_{i,j}$:
#
# $$u_{i,j}=\frac{(\Delta x)^2\,(u_{i,j+1}+u_{i,j-1})+(\Delta y)^2\,(u_{i+1,j}+u_{i-1,j})}{2\,[(\Delta x)^2+(\Delta y)^2]}$$
#
#
# $$u_{i,j}=\frac{1}{2\,[(\Delta x)^2+(\Delta y)^2]}\left[(\Delta x)^2\,(u_{i,j+1}+u_{i,j-1})+(\Delta y)^2\,(u_{i+1,j}+u_{i-1,j})\right]$$

# %%
# Coefficient in front:

coef = 0.5/(dx**2 + dy**2)

#print(coef)

# %% [markdown]
# ### Guess:

# %%
# Empty matrix for the numerical sln

u_numer = np.zeros((ny, nx))

#print(u_numer.shape)

# %%
# Boundary conditions

u_numer[0, :] = 0.
u_numer[:, 0] = 0.

u_numer[-1, :] = np.sin(x)/np.sin(a)
u_numer[:, -1] = np.sinh(y)/np.sinh(b)

# %%
#print(u_numer)

# %%
plt.figure(figsize=(5,4))

plt.pcolor(x_2d, y_2d, u_numer, cmap = "viridis")

plt.show()

# %%
# Plotting
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Plot the surface.
surf = ax.plot_surface(x_2d, y_2d, u_numer, cmap = 'viridis', linewidth=0, antialiased=False)

plt.xlabel(r"$x$")
plt.ylabel(r"$y$")

plt.show()

# %% [markdown]
# $$u_{i,j}=\frac{1}{2\,[(\Delta x)^2+(\Delta y)^2]}\left[(\Delta x)^2\,(u_{i,j+1}+u_{i,j-1})+(\Delta y)^2\,(u_{i+1,j}+u_{i-1,j})\right]$$

# %%
for j in range(1, nx - 1):
    for i in range(1, ny - 1):

        u_numer[i, j] = coef*(dx**2*(u_numer[i+1, j]\
        + u_numer[i-1, j]) + dy**2*(u_numer[i, j+1]\
        + u_numer[i, j-1]))

# %%
plt.figure(figsize=(5,4))

plt.pcolor(x_2d, y_2d, u_numer, cmap = "viridis")

plt.show()

# %% [markdown]
# ## Iterative step:

# %%
# For loop to fill up the solution

iter_number = 1000

for k in range(iter_number):

    for j in range(1, nx - 1):
        for i in range(1, ny - 1):

            u_numer[i, j] = coef*(dx**2*(u_numer[i+1, j]\
            + u_numer[i-1, j]) + dy**2*(u_numer[i, j+1]\
            + u_numer[i, j-1]))

# %%
plt.figure(figsize=(5,4))

plt.pcolor(x_2d, y_2d, u_numer, cmap = "viridis")

plt.show()

# %%
# Plotting

plt.figure(figsize=(6,5))

surf_numer = plt.pcolor(x_2d, y_2d, u_numer, cmap = 'inferno')

plt.colorbar(surf_numer)

plt.title("Numerical solution")

plt.show()

# %%
# Plotting
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Plot the surface.
surf = ax.plot_surface(x_2d, y_2d, u_numer, cmap = 'inferno', linewidth=0, antialiased=False)

plt.xlabel(r"$x$")
plt.ylabel(r"$y$")

plt.show()

# %% [markdown]
# ## Error calculation/map:

# %%
# Plotting

plt.figure(figsize=(6,5))

surf_err = plt.pcolor(x_2d, y_2d, u_numer - u_exact_sln, cmap = 'Blues')

plt.colorbar(surf_err)

plt.title("Error in the numerical sln.")

plt.show()

# %% [markdown]
# ### $L_2$ norm
#
# $||\epsilon||_2=\frac{1}{N}\sqrt{\sum |u_{numer}-u_{exact}|^2}$

# %%
n_value = u_exact_sln.size
err_2 = (1./n_value)*(np.sqrt(np.sum(abs(u_numer - u_exact_sln)**2)))

print(err_2)
# Out:
# 234569499531.5191

# %% [markdown]
# ### Metric implementation:

# %%
# Guess step
u_numer = np.zeros((ny, nx))

# Boundary conditions

u_numer[0, :] = 0.
u_numer[:, 0] = 0.

u_numer[-1, :] = np.sin(x)/np.sin(a)
u_numer[:, -1] = np.sinh(y)/np.sinh(b)

# Save initial map
u_old = u_numer.copy()

# Iteration step

# For loop to fill up the solution
iter_number = 1000

for k in range(iter_number):
    u_old = u_numer.copy()

    for j in range(1, nx - 1):
        for i in range(1, ny - 1):

            u_numer[i, j] = coef*(dx**2*(u_numer[i+1, j]\
            + u_numer[i-1, j]) + dy**2*(u_numer[i, j+1]\
            + u_numer[i, j-1]))

    d = np.max(np.abs(u_numer - u_old))
    print(k,d)
# Out:
# 0 644487837543882.6
# 1 305197452629010.25
# 2 168889509908961.75
# 3 119968899124962.28
# 4 93287872054220.97
# 5 73861681895966.75
# 6 61001782317347.06
# 7 53266080519342.03
# 8 46664870484878.69
# 9 41146821986790.75
# 10 36544140215753.875
# 11 33401965574631.438
# 12 30710914589913.438
# 13 28297693998690.312
# 14 26142527481838.875
# 15 24219194234096.0
# 16 22597998590208.0
# 17 21324585155546.875
# 18 20141757382211.5
# 19 19046133032252.75
# 20 18032604559169.0
# 21 17095327475656.125
# 22 16228287508952.375
# 23 15508745279774.812
# 24 14870573515539.938
# 25 14266824640925.062
# 26 13696216508629.875
# 27 13157214100975.375
# 28 12648154710682.562
# 29 12167331356203.25
# 30 11713047584406.062
# 31 11336715064477.062
# 32 10980395978523.25
# 33 10639029679505.812
# 34 10312131907922.062
# 35 9999167389093.125
# 36 9699571825746.625
# 37 9412768025385.188
# 38 9138177627572.25
# 39 8877799883335.438
# 40 8655271188671.0
# 41 8440128708602.5625
# 42 8232193515672.6875
# 43 8031267615090.3125
# 44 7837140147782.5625
# 45 7649592264089.1875
# 46 7468400938100.625
# 47 7293341936996.875
# 48 7124192115982.0
# 49 6963153375794.875
# 50 6821476813055.9375
# 51 6683652079694.8125
# 52 6549596698337.625
# 53 6419222804105.75
# 54 6292438708981.75
# 55 6169150187750.1875
# 56 6049261532121.625
# 57 5932676411746.1875
# 58 5819298574294.4375
# 59 5709032411399.3125
# 60 5602814168668.4375
# 61 5508183087629.125
# 62 5415696810835.0
# 63 5325315142294.5625
# 64 5236996140363.1875
# 65 5150696575315.0
# 66 5066372318244.5
# 67 4983978670926.6875
# 68 4903470644900.25
# 69 4824803196867.6875
# 70 4747931426512.375
# 71 4672810741979.75
# 72 4599396997539.9375
# 73 4533505977327.5625
# 74 4469080790058.8125
# 75 4405895320427.625
# 76 4343928246270.5625
# 77 4283157766625.0625
# 78 4223561733001.75
# 79 4165117763646.4375
# 80 4107803342812.875
# 81 4051595906830.9375
# 82 3996472918533.5625
# 83 3942411931426.5
# 84 3889390644818.0
# 85 3837386950983.6875
# 86 3789274803615.375
# 87 3742994906899.4375
# 88 3697478569586.5625
# 89 3652714347919.3125
# 90 3608690605659.4375
# 91 3565395562596.125
# 92 3522817337622.9375
# 93 3480943986942.3125
# 94 3439763537892.8125
# 95 3399264018849.375
# 96 3359433485594.0625
# 97 3320260044521.4375
# 98 3281731872998.0625
# 99 3243837237171.8125
# 100 3207655824900.375
# 101 3173542815044.0
# 102 3139918176061.625
# 103 3106775471111.5625
# 104 3074108180938.375
# 105 3041909723208.875
# 106 3010173469961.25
# 107 2978892763330.8125
# 108 2948060929708.125
# 109 2917671292469.25
# 110 2887717183402.0
# 111 2858191952947.25
# 112 2829088979358.8125
# 113 2800401676877.625
# 114 2772123503009.5625
# 115 2744249080200.75
# 116 2718547540755.5
# 117 2693168630049.0
# 118 2668108576622.0625
# 119 2643363571889.375
# 120 2618929778361.0
# 121 2594803337157.5625
# 122 2570980374872.6875
# 123 2547457009833.0625
# 124 2524229357804.6875
# 125 2501293537186.875
# 126 2478645673734.6875
# 127 2456281904846.3125
# 128 2434198383450.6875
# 129 2412391281522.625
# 130 2390856793260.1875
# 131 2369591137946.125
# 132 2349214491260.1875
# 133 2329701296453.375
# 134 2310405006757.0
# 135 2291323314431.125
# 136 2272453898014.375
# 137 2253794425738.0625
# 138 2235342558676.5
# 139 2217095953652.3125
# 140 2199052265913.8125
# 141 2181209151600.0
# 142 2163564270007.6875
# 143 2146115285674.8125
# 144 2128859870291.6875
# 145 2111795704453.4375
# 146 2094920479263.4375
# 147 2078231897798.25
# 148 2061727676444.4375
# 149 2045405546115.4375
# 150 2030070670618.6875
# 151 2014974892234.625
# 152 2000028855518.75
# 153 1985231109806.0
# 154 1970580199367.375
# 155 1956074664923.0625
# 156 1941713045049.875
# 157 1927493877489.625
# 158 1913415700365.25
# 159 1899477053310.1875
# 160 1885676478515.6875
# 161 1872012521701.3125
# 162 1858483733014.625
# 163 1845088667862.5
# 164 1831825887679.4375
# 165 1818693960636.5625
# 166 1805691462294.625
# 167 1792816976204.9375
# 168 1780215656394.4375
# 169 1768240106130.5
# 170 1756371293452.6875
# 171 1744608285437.375
# 172 1732950146649.6875
# 173 1721395939898.25
# 174 1709944726944.5
# 175 1698595569165.0625
# 176 1687347528174.0
# 177 1676199666403.4375
# 178 1665151047647.9375
# 179 1654200737571.75
# 180 1643347804184.125
# 181 1632591318281.3125
# 182 1621930353859.5
# 183 1611363988498.8125
# 184 1600891303721.0625
# 185 1590511385321.5
# 186 1580223323677.5
# 187 1570026214033.1875
# 188 1560140923045.1875
# 189 1550600153247.5
# 190 1541136309006.375
# 191 1531748773559.9375
# 192 1522436929294.6875
# 193 1513200158114.375
# 194 1504037841787.375
# 195 1494949362274.6875
# 196 1485934102037.9375
# 197 1476991444330.5
# 198 1468120773470.0625
# 199 1459321475097.0625
# 200 1450592936414.125
# 201 1441934546414.8125
# 202 1433345696095.4375
# 203 1424825778654.1875
# 204 1416374189678.9375
# 205 1407990327321.1875
# 206 1399673592460.3125
# 207 1391423388855.375
# 208 1383239123287.375
# 209 1375340997305.1875
# 210 1367644683024.3125
# 211 1360004833302.6875
# 212 1352421031611.8125
# 213 1344892861227.8125
# 214 1337419905419.0
# 215 1330001747623.6875
# 216 1322637971618.5625
# 217 1315328161677.875
# 218 1308071902725.0625
# 219 1300868780474.125
# 220 1293718381565.9375
# 221 1286620293694.5
# 222 1279574105728.0
# 223 1272579407821.8125
# 224 1265635791525.8125
# 225 1258742849885.125
# 226 1251900177534.75
# 227 1245107370789.3125
# 228 1238364027726.4375
# 229 1231669748266.0
# 230 1225024134243.5
# 231 1218613169180.5625
# 232 1212336074022.875
# 233 1206101108789.3125
# 234 1199907986599.875
# 235 1193756420626.0625
# 236 1187646124189.3125
# 237 1181576810855.875
# 238 1175548194526.0625
# 239 1169559989519.5
# 240 1163611910656.625
# 241 1157703673334.8125
# 242 1151834993602.1875
# 243 1146005588226.4375
# 244 1140215174761.5
# 245 1134463471608.625
# 246 1128750198076.5625
# 247 1123075074437.0625
# 248 1117437821978.1875
# 249 1111838163053.5625
# 250 1106275821130.5
# 251 1100750520834.375
# 252 1095261987990.5
# 253 1089809949664.0625
# 254 1084534483146.625
# 255 1079364637944.9375
# 256 1074226693103.0
# 257 1069120447434.5
# 258 1064045699883.9375
# 259 1059002249579.5625
# 260 1053989895885.75
# 261 1049008438451.75
# 262 1044057677258.75
# 263 1039137412664.75
# 264 1034247445447.25
# 265 1029387576844.0
# 266 1024557608592.0625
# 267 1019757342964.375
# 268 1014986582805.1875
# 269 1010245131563.75
# 270 1005532793325.9375
# 271 1000849372844.1875
# 272 996194675567.0625
# 273 991568507665.875
# 274 986970676060.875
# 275 982400988445.625
# 276 977859253310.1875
# 277 973345279963.0625
# 278 968952397842.0
# 279 964657172477.125
# 280 960386424887.5625
# 281 956140011621.625
# 282 951917789369.75
# 283 947719614994.75
# 284 943545345560.875
# 285 939394838361.8125
# 286 935267950946.8125
# 287 931164541146.125
# 288 927084467096.5
# 289 923027587262.6875
# 290 918993760461.125
# 291 914982845880.75
# 292 910994703103.25
# 293 907029192122.5625
# 294 903086173363.625
# 295 899165507700.0625
# 296 895267056470.0625
# 297 891390681494.5625
# 298 887536245090.1875
# 299 883703610085.5
# 300 879892639833.875
# 301 876103198227.375
# 302 872335149708.6875
# 303 868639261578.5625
# 304 865042636417.9375
# 305 861465021323.25
# 306 857906312433.875
# 307 854366406018.8125
# 308 850845198493.4375
# 309 847342586437.125
# 310 843858466608.5625
# 311 840392735961.375
# 312 836945291659.3125
# 313 833516031089.25
# 314 830104851877.0
# 315 826711651897.875
# 316 823336329291.125
# 317 819978782471.125
# 318 816638910138.8125
# 319 813316611293.3125
# 320 810011785241.4375
# 321 806724331609.0625
# 322 803454150349.6875
# 323 800201141754.625
# 324 796965206460.5625
# 325 793746245459.0
# 326 790544160104.0625
# 327 787358852119.8125
# 328 784190223608.0
# 329 781052639143.1875
# 330 778019663620.4375
# 331 775001614759.1875
# 332 771998416296.625
# 333 769009992079.875
# 334 766036266074.75
# 335 763077162377.8125
# 336 760132605224.0625
# 337 757202518996.6875
# 338 754286828236.0625
# 339 751385457647.875
# 340 748498332111.4375
# 341 745625376687.625
# 342 742766516625.875
# 343 739921677372.125
# 344 737090784575.375
# 345 734273764094.5
# 346 731470542004.0625
# 347 728681044601.5
# 348 725905198412.3125
# 349 723142930195.6875
# 350 720394166950.125
# 351 717658835918.875
# 352 714936864593.9375
# 353 712228180721.9375
# 354 709532712308.0
# 355 706850387620.125
# 356 704181135193.5
# 357 701591702962.125
# 358 699029509243.125
# 359 696479097329.375
# 360 693940410578.8125
# 361 691413392445.5
# 362 688897986484.6875
# 363 686394136359.125
# 364 683901785844.4375
# 365 681420878833.875
# 366 678951359344.625
# 367 676493171521.625
# 368 674046259642.8125
# 369 671610568123.6875
# 370 669186041522.125
# 371 666772624541.375
# 372 664370262036.125
# 373 661978899014.5625
# 374 659598480643.25
# 375 657228952250.625
# 376 654870259330.0
# 377 652522347543.6875
# 378 650185162725.6875
# 379 647858650884.9375
# 380 645542758208.25
# 381 643237431063.375
# 382 640942616001.625
# 383 638658259760.125
# 384 636384309264.8125
# 385 634148047526.6875
# 386 631960305779.875
# 387 629781997342.1875
# 388 627613079573.0625
# 389 625453509906.8125
# 390 623303245857.6875
# 391 621162245022.125
# 392 619030465083.375
# 393 616907863813.6875
# 394 614794399077.875
# 395 612690028836.75
# 396 610594711149.875
# 397 608508404177.4375
# 398 606431066184.875
# 399 604362655543.9375
# 400 602303130735.9375
# 401 600252450354.0625
# 402 598210573105.9375
# 403 596177457815.75
# 404 594153063426.4375
# 405 592137349001.625
# 406 590130273728.5
# 407 588131796918.625
# 408 586141878010.6875
# 409 584160476571.8125
# 410 582187552299.875
# 411 580223065024.4375
# 412 578266974709.125
# 413 576319241452.3125
# 414 574379825489.5
# 415 572498794693.875
# 416 570628593487.625
# 417 568765976627.1875
# 418 566910911709.75
# 419 565063366395.1875
# 420 563223308406.875
# 421 561390705534.5
# 422 559565525635.8125
# 423 557747736639.3125
# 424 555937306544.8125
# 425 554134203426.875
# 426 552338395435.0625
# 427 550549850797.1875
# 428 548768537819.625
# 429 546994424889.9375
# 430 545227480477.875
# 431 543467673137.0625
# 432 541714971506.5625
# 433 539969344312.125
# 434 538230760367.5
# 435 536499188576.125
# 436 534774597931.75
# 437 533056957520.375
# 438 531346236520.75
# 439 529642404205.875
# 440 527945429944.3125
# 441 526255283200.8125
# 442 524571933537.0625
# 443 522895350613.4375
# 444 521225504189.375
# 445 519579552208.0625
# 446 517966237266.8125
# 447 516359095326.8125
# 448 514758101464.0
# 449 513163230802.1875
# 450 511574458515.3125
# 451 509991759828.0
# 452 508415110017.875
# 453 506844484415.6875
# 454 505279858407.1875
# 455 503721207434.0625
# 456 502168506995.75
# 457 500621732649.0625
# 458 499080860010.875
# 459 497545864758.375
# 460 496016722629.8125
# 461 494493409426.125
# 462 492975901011.5625
# 463 491464173314.4375
# 464 489958202328.4375
# 465 488457964112.875
# 466 486963434793.9375
# 467 485474590565.6875
# 468 483991407690.0
# 469 482513862498.25
# 470 481041931391.1875
# 471 479575590840.25
# 472 478114817388.1875
# 473 476659587648.9375
# 474 475209878309.3125
# 475 473765666128.5
# 476 472326927939.75
# 477 470923007864.375
# 478 469530855122.5625
# 479 468143738456.75
# 480 466761638563.1875
# 481 465384536177.0625
# 482 464012412073.3125
# 483 462645247067.75
# 484 461283022016.6875
# 485 459925717819.625
# 486 458573315418.4375
# 487 457225795798.9375
# 488 455883139990.9375
# 489 454545329069.875
# 490 453212344156.3125
# 491 451884166417.5625
# 492 450560777067.9375
# 493 449242157369.5
# 494 447928288632.0
# 495 446619152214.3125
# 496 445314729524.75
# 497 444015002021.625
# 498 442719951212.6875
# 499 441429558657.9375
# 500 440143805967.5
# 501 438862674804.125
# 502 437586146882.4375
# 503 436314203969.8125
# 504 435046827887.0
# 505 433784000508.0
# 506 432525703760.4375
# 507 431271919626.8125
# 508 430022630143.9375
# 509 428789593796.6875
# 510 427578314743.1875
# 511 426371191858.75
# 512 425168210015.5625
# 513 423969354116.625
# 514 422774609095.5
# 515 421583959917.625
# 516 420397391580.4375
# 517 419214889113.875
# 518 418036437581.1875
# 519 416862022078.625
# 520 415691627737.1875
# 521 414525239721.875
# 522 413362843232.8125
# 523 412204423505.125
# 524 411049965810.125
# 525 409899455454.9375
# 526 408752877783.375
# 527 407610218176.125
# 528 406471462051.0625
# 529 405336594863.875
# 530 404205602108.0
# 531 403078469315.125
# 532 401955182055.875
# 533 400835725939.6875
# 534 399720086614.6875
# 535 398608249769.4375
# 536 397500201131.25
# 537 396395926468.3125
# 538 395295411588.625
# 539 394198642341.0625
# 540 393105604615.0
# 541 392016284340.9375
# 542 390930667490.8125
# 543 389865531642.625
# 544 388811224821.0
# 545 387760356865.5
# 546 386712915842.4375
# 547 385668889842.0
# 548 384628266979.625
# 549 383591035395.1875
# 550 382557183254.625
# 551 381526698748.75
# 552 380499570095.0
# 553 379475785537.25
# 554 378455333345.3125
# 555 377438201816.5
# 556 376424379275.1875
# 557 375413854072.8125
# 558 374406614589.1875
# 559 373402649231.625
# 560 372401946435.75
# 561 371404494665.9375
# 562 370410282414.75
# 563 369419298204.3125
# 564 368431530585.1875
# 565 367446968138.1875
# 566 366465599472.6875
# 567 365487413228.6875
# 568 364512398075.625
# 569 363540542713.375
# 570 362571835871.875
# 571 361606266311.8125
# 572 360643822824.375
# 573 359684494231.8125
# 574 358728269387.0625
# 575 357775137174.3125
# 576 356825086509.0
# 577 355878106338.1875
# 578 354952551978.125
# 579 354031495687.5
# 580 353113301505.5625
# 581 352197959941.25
# 582 351285461522.5
# 583 350375796797.3125
# 584 349468956333.4375
# 585 348564930718.5
# 586 347663710561.125
# 587 346765286489.8125
# 588 345869649154.1875
# 589 344976789224.75
# 590 344086697393.0625
# 591 343199364372.1875
# 592 342314780896.125
# 593 341432937721.375
# 594 340553825625.5625
# 595 339677435408.5625
# 596 338803757892.5
# 597 337932783921.625
# 598 337064504362.6875
# 599 336198910105.0625
# 600 335335992060.5625
# 601 334475741164.5
# 602 333618148374.6875
# 603 332763204671.875
# 604 331910901060.875
# 605 331061228568.75
# 606 330214178246.9375
# 607 329369741170.125
# 608 328527908436.625
# 609 327688671168.4375
# 610 326852020511.75
# 611 326017947636.625
# 612 325186443737.0625
# 613 324358481479.6875
# 614 323548697693.4375
# 615 322741316387.375
# 616 321936329939.125
# 617 321133730742.125
# 618 320333511205.4375
# 619 319535663753.75
# 620 318740180827.75
# 621 317947054884.125
# 622 317156278395.8125
# 623 316367843852.3125
# 624 315581743759.125
# 625 314797970638.4375
# 626 314016517029.6875
# 627 313237375488.3125
# 628 312460538587.375
# 629 311685998916.4375
# 630 310913749082.9375
# 631 310143781710.8125
# 632 309376089441.75
# 633 308610664935.125
# 634 307847500867.4375
# 635 307086589933.375
# 636 306327924844.5625
# 637 305571498331.5
# 638 304817303141.8125
# 639 304065332041.5
# 640 303315577814.875
# 641 302568033263.5625
# 642 301822691208.75
# 643 301079544488.5625
# 644 300338585960.6875
# 645 299599808500.5
# 646 298863205002.1875
# 647 298128768378.5625
# 648 297396491560.9375
# 649 296666367499.5625
# 650 295939612341.5625
# 651 295227620084.125
# 652 294517647628.3125
# 653 293809688822.1875
# 654 293103737526.375
# 655 292399787614.375
# 656 291697832971.8125
# 657 290997867497.625
# 658 290299885103.4375
# 659 289603879713.9375
# 660 288909845266.9375
# 661 288217775713.0625
# 662 287527665016.8125
# 663 286839507155.25
# 664 286153296119.375
# 665 285469025913.5625
# 666 284786690555.5625
# 667 284106284077.0
# 668 283427800523.125
# 669 282751233952.75
# 670 282076578438.625
# 671 281403828067.5625
# 672 280732976940.25
# 673 280064019171.375
# 674 279396948889.4375
# 675 278731760237.5625
# 676 278068447372.625
# 677 277407004466.0
# 678 276747425703.3125
# 679 276089705284.5
# 680 275433837423.9375
# 681 274779816350.1875
# 682 274127636306.75
# 683 273477291551.25
# 684 272828776356.0625
# 685 272182085008.125
# 686 271537211809.0625
# 687 270894151075.0
# 688 270252897137.1875
# 689 269624515056.1875
# 690 268998347503.5
# 691 268373880571.9375
# 692 267751109274.875
# 693 267130028636.125
# 694 266510633689.75
# 695 265892919479.8125
# 696 265276881061.1875
# 697 264662513499.4375
# 698 264049811870.25
# 699 263438771259.875
# 700 262829386765.625
# 701 262221653495.25
# 702 261615566567.3125
# 703 261011121111.25
# 704 260408312267.375
# 705 259807135186.75
# 706 259207585031.8125
# 707 258609656975.3125
# 708 258013346201.75
# 709 257418647906.5
# 710 256825557295.6875
# 711 256234069587.1875
# 712 255644180009.75
# 713 255055883803.625
# 714 254469176220.0
# 715 253884052521.4375
# 716 253300507982.5625
# 717 252718537888.25
# 718 252138137535.6875
# 719 251559302233.125
# 720 250982027300.25
# 721 250406308068.6875
# 722 249832139881.0625
# 723 249259518092.0
# 724 248688438067.3125
# 725 248118895184.8125
# 726 247550884833.75
# 727 246984402415.0
# 728 246425056414.25
# 729 245871248839.625
# 730 245318883349.875
# 731 244767955872.4375
# 732 244218462343.1875
# 733 243670398706.5
# 734 243123760915.125
# 735 242578544930.0625
# 736 242034746721.5625
# 737 241492362267.6875
# 738 240951387555.625
# 739 240411818580.9375
# 740 239873651348.0625
# 741 239336881870.125
# 742 238801506168.75
# 743 238267520274.9375
# 744 237734920227.75
# 745 237203702075.9375
# 746 236673861876.3125
# 747 236145395695.125
# 748 235618299607.6875
# 749 235092569697.625
# 750 234568202058.3125
# 751 234045192791.5625
# 752 233523538008.5625
# 753 233003233829.5625
# 754 232484276383.6875
# 755 231966661809.375
# 756 231450386254.0625
# 757 230935445874.625
# 758 230421836836.6875
# 759 229909555315.375
# 760 229398597494.9375
# 761 228888959568.9375
# 762 228380637740.0
# 763 227873628220.3125
# 764 227367927230.9375
# 765 226863531002.75
# 766 226360435775.375
# 767 225858637798.1875
# 768 225358133329.625
# 769 224865577926.875
# 770 224375679113.25
# 771 223887004441.375
# 772 223399550577.125
# 773 222913314193.0
# 774 222428291968.375
# 775 221944480590.25
# 776 221461876751.625
# 777 220980477153.375
# 778 220500278502.9375
# 779 220021277515.25
# 780 219543470912.0
# 781 219066855421.9375
# 782 218591427781.375
# 783 218117184733.5625
# 784 217644123028.5
# 785 217172239424.5
# 786 216701530685.8125
# 787 216231993584.8125
# 788 215763624901.0
# 789 215296421420.75
# 790 214830379938.0
# 791 214365497254.4375
# 792 213901770178.0625
# 793 213439195525.375
# 794 212977770119.1875
# 795 212517490790.625
# 796 212058354377.375
# 797 211600357725.0625
# 798 211143497686.875
# 799 210687771122.5
# 800 210233174900.0625
# 801 209779705894.8125
# 802 209327360989.375
# 803 208876137073.6875
# 804 208426031045.5
# 805 207977039810.0625
# 806 207529160279.75
# 807 207082389374.6875
# 808 206636724022.625
# 809 206192161158.5
# 810 205748697725.375
# 811 205309628033.875
# 812 204875056978.25
# 813 204441529033.75
# 814 204009041460.375
# 815 203577591523.9375
# 816 203147176496.0625
# 817 202717793654.0625
# 818 202289440280.8125
# 819 201862113665.5625
# 820 201435811102.75
# 821 201010529893.1875
# 822 200586267342.9375
# 823 200163020764.5625
# 824 199740787476.0
# 825 199319564801.4375
# 826 198899350070.5625
# 827 198480140619.375
# 828 198061933789.5625
# 829 197644726928.75
# 830 197228517390.75
# 831 196813302534.9375
# 832 196399079726.9375
# 833 195985846338.375
# 834 195573599746.6875
# 835 195162337335.375
# 836 194752056493.9375
# 837 194342754617.6875
# 838 193934429108.5625
# 839 193527077373.875
# 840 193120696827.4375
# 841 192715284888.6875
# 842 192310838983.375
# 843 191907356543.1875
# 844 191504835005.9375
# 845 191103271815.6875
# 846 190702664421.9375
# 847 190303010281.3125
# 848 189904306855.3125
# 849 189506551612.4375
# 850 189109742027.0
# 851 188713875579.0625
# 852 188318949755.3125
# 853 187924962048.0625
# 854 187531909956.375
# 855 187141377226.03125
# 856 186755749529.84375
# 857 186371011789.59375
# 858 185987161752.125
# 859 185604197168.4375
# 860 185222115794.875
# 861 184840915392.5625
# 862 184460593727.0
# 863 184081148568.9375
# 864 183702577693.625
# 865 183324878881.3125
# 866 182948049916.875
# 867 182572088590.3125
# 868 182196992696.125
# 869 181822760034.125
# 870 181449388408.375
# 871 181076875628.375
# 872 180705219508.125
# 873 180334417866.5
# 874 179964468527.625
# 875 179595369320.125
# 876 179227118077.625
# 877 178859712638.625
# 878 178493150846.6875
# 879 178127430550.25
# 880 177762549602.375
# 881 177398505861.4375
# 882 177035297190.375
# 883 176672921457.1875
# 884 176311376534.9375
# 885 175950660301.5625
# 886 175590770639.6875
# 887 175231705437.1875
# 888 174873462586.75
# 889 174516039985.9375
# 890 174159435537.25
# 891 173803647148.4375
# 892 173448672731.5
# 893 173094510204.4375
# 894 172741157489.0625
# 895 172388612512.875
# 896 172036873208.125
# 897 171685937511.9375
# 898 171335803366.625
# 899 170986468719.0625
# 900 170637931521.375
# 901 170290189730.5625
# 902 169946869485.1875
# 903 169605266950.9375
# 904 169264423066.6875
# 905 168924335982.375
# 906 168585003852.3125
# 907 168246424834.46875
# 908 167908597090.9375
# 909 167571518787.59375
# 910 167235188094.5625
# 911 166899603185.59375
# 912 166564762238.71875
# 913 166230663435.84375
# 914 165897304962.71875
# 915 165564685009.40625
# 916 165232801769.59375
# 917 164901653441.1875
# 918 164571238226.09375
# 919 164241554330.1875
# 920 163912599963.09375
# 921 163584373338.96875
# 922 163256872675.5625
# 923 162930096194.75
# 924 162604042122.34375
# 925 162278708688.40625
# 926 161954094126.71875
# 927 161630196675.3125
# 928 161307014576.0
# 929 160984546074.90625
# 930 160662789421.9375
# 931 160341742871.125
# 932 160021404680.3125
# 933 159701773111.9375
# 934 159382846431.6875
# 935 159064622909.6875
# 936 158747100820.375
# 937 158430278441.5
# 938 158114154055.3125
# 939 157798725948.0625
# 940 157483992409.875
# 941 157169951734.9375
# 942 156856602221.4375
# 943 156543942171.8125
# 944 156231969892.0
# 945 155920683692.4375
# 946 155610081887.3125
# 947 155300162795.0625
# 948 154990924737.8125
# 949 154682366041.875
# 950 154374485037.6875
# 951 154068862521.96875
# 952 153766041802.59375
# 953 153463869248.25
# 954 153162343339.875
# 955 152861462561.71875
# 956 152561225401.5
# 957 152261630349.90625
# 958 151962675900.84375
# 959 151664360551.96875
# 960 151366682803.65625
# 961 151069641159.75
# 962 150773234127.40625
# 963 150477460217.0
# 964 150182317942.1875
# 965 149887805819.84375
# 966 149593922370.25
# 967 149300666116.625
# 968 149008035585.96875
# 969 148716029308.03125
# 970 148424645816.28125
# 971 148133883646.9375
# 972 147843741340.1875
# 973 147554217438.75
# 974 147265310489.09375
# 975 146977019040.90625
# 976 146689341646.875
# 977 146402276863.25
# 978 146115823249.34375
# 979 145829979367.84375
# 980 145544743784.6875
# 981 145260115069.125
# 982 144976091793.5625
# 983 144692672533.625
# 984 144409855868.34375
# 985 144127640380.0
# 986 143846024654.09375
# 987 143565007279.25
# 988 143284586847.59375
# 989 143004761954.28125
# 990 142725531197.71875
# 991 142446893179.9375
# 992 142168846505.6875
# 993 141891389783.25
# 994 141614521624.09375
# 995 141338240643.03125
# 996 141062545457.875
# 997 140787434690.03125
# 998 140512906963.65625
# 999 140238960906.53125

# %%
print(np.unique(u_numer - u_old))
# Out:
# [-1.40238961e+11 -1.40224859e+11 -1.40211250e+11 ...  1.40091756e+11
#   1.40178619e+11  1.40197666e+11]

# %%
# Plotting

plt.figure(figsize=(6,5))

surf_numer = plt.pcolor(x_2d, y_2d, u_numer - u_old, cmap = 'inferno')

plt.colorbar(surf_numer)

plt.title("Numerical solution")

plt.show()
